# %%
import numpy as np
import os
import cv2
import csv
import pandas as pd
from pyspark.sql import SQLContext
from pyspark import SparkConf
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
def save_img():
    X_pics = np.zeros((200,3,320,320),dtype=np.float32)
    root_dir = '/home/msragpu/cellwork/data/0_test_modify/'
    imageList = os.listdir(root_dir)
    q = 0
    dic = {}
    
    for n in imageList:
        image_name = n
        n = root_dir + n
        img = cv2.imread(n, 3)
        if img is None:
            continue
        image = img.tolist()
        dic[image_name] = image
    return dic

my_dict = save_img()
'''
with open('picture.csv', 'wb') as f:
    w = csv.DictWriter(f, my_dict.keys())
    w.writeheader()
    w.writerow(my_dict)
'''
np.save('my_file.npy', my_dict)

# %%
X_pics = np.zeros((200,3,320,320),dtype=np.float32)
root_dir = '/home/msragpu/cellwork/data/0_test_modify/'
imageList = os.listdir(root_dir)
q = 0
dic = {}
    
n = imageList[0]:
image_name = n
n = root_dir + n
img = cv2.imread(n, 3)
if img is None:
    continue
image = img.tolist()
print (image)
dic[image_name] = image
return dic

# %%
my_dict = np.load('my_file.npy') 

sqlContext = SQLContext(sc)
df = pd.DataFrame(my_dict.item().items(),columns=['image_name', 'image_array'])
sparkdf = sqlContext.createDataFrame(df)
#sparkdf.show()

# %%
sparkdf.collect()

# %%
def show_image(name, array):
    image = cv2.imwrite(('./out.jpg'), array)
    plt.imshow(Image.open('./out.jpg'))
    plt.axis('off')
    plt.set_title(name, color="black")
    plt.show()
    
def search_by_name(sparkdf,name):
    result = sparkdf.collect()
    if [n.image_name for n in result].index(result) != None:
        show_image(name, np.array(result[index].image_array,dtype=int))
    else:
        print ('no existence')
    
def search_by_index(sparkdf,index):
    result = sparkdf.collect()[index]
    array, name = result.image_array, result.image_name
    array = np.array(array,dtype=int)
    show_image(name, array)
    
def compute_RGB_mean():
    mean = np.zeros((3,),dtype='np.float32')
    for n in [n.image_array for n in result]:
        mean += array.mean(axis = 0).mean(axis = 0)/200
    print ("RGB mean value is", mean)
    
def crop_by_index(sparkdf, index, size):
    result = sparkdf.collect()[index]
    array, name = result.image_array, result.image_name
    array = np.array(array,dtype=int)
    array_resize = array[160-size/2:160+size/2, 160-size/2:160+size/2, 3]
    show_image(name, array_resize)

# %%
array = sparkdf.collect()[0].image_array
array = np.array(array,dtype=int)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-7e5f8a1436c2> in <module>()
#       1 array = sparkdf.collect()[0].image_array
#       2 array = np.array(array,dtype=int)
# ----> 3 show_image(array)
#
# NameError: name 'show_image' is not defined

# %%
mean = np.zeros((3,),dtype=np.float32)
mean = mean + array.mean(axis = 0).mean(axis = 0)
print (mean)
# Out:
# [ 161.36717773  122.9350293   165.18984375]

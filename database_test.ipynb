# %%
import functions 

#functions.save_img('./data/')

pandasdf = functions.load_dataframe()
sqlContext = SQLContext(sc)
sparkdf = sqlContext.createDataFrame(pandasdf).collect()

# %%
functions.search_by_index(sparkdf,1)
functions.search_by_index(sparkdf,50)
functions.search_by_index(sparkdf,199)

# %%
functions.crop_by_index(sparkdf, 5, 60)
functions.crop_by_index(sparkdf, 5, 90)
functions.crop_by_index(sparkdf, 5, 150)

# %%
functions.compute_RGB_mean(sparkdf)
# Out:
# ('RGB mean value is', array([ 187.04933167,  160.47349548,  204.93003845], dtype=float32))

# %%
import sys
sys.path.append('/opt/ASAP/bin')
import multiresolutionimageinterface as mir
reader = mir.MultiResolutionImageReader()
mr_image = reader.open('/disk2/Train_Tumor/Tumor_001.tif')
print(mr_image)
# Out:
# <Swig Object of type 'std::shared_ptr< MultiResolutionImage > *' at 0x7fd9580b5298>

# %%
import wholeslidefilters as wsf
ndwsf = wsf.NucleiDetectionWholeSlideFilter()
ndwsf.setInput(mr_image)

# %%
ndwsf.setAlpha(2)
ndwsf.setBeta(0.01)
ndwsf.setThreshold(0.01)
ndwsf.setMaximumRadius(5.00)
ndwsf.setMinimumRadius(1.50)
ndwsf.setRadiusStep(1)
# Out:
# 2.0

# %%
ndwsf.process()

# %%
# Out:
# Help on module wholeslidefilters:
#
# NAME
#     wholeslidefilters
#
# FILE
#     /opt/ASAP/bin/wholeslidefilters.py
#
# DESCRIPTION
#     # This file was automatically generated by SWIG (http://www.swig.org).
#     # Version 3.0.8
#     #
#     # Do not make changes to this file unless you know what you are doing--modify
#     # the SWIG interface file instead.
#
# CLASSES
#     __builtin__.SwigPyObject(__builtin__.object)
#         ArithmeticWholeSlideFilter
#         ConnectedComponentsWholeSlideFilter
#         DistanceTransformWholeSlideFilter
#         LabelStatisticsWholeSlideFilter
#         NucleiDetectionWholeSlideFilter
#         SwigPyIterator
#         ThresholdWholeSlideFilter
#         vector_double
#         vector_float
#         vector_int
#         vector_long_long
#         vector_string
#         vector_uint
#         vector_unsigned_long_long
#         vector_vector_float
#
#     class ArithmeticWholeSlideFilter(__builtin__.SwigPyObject)
#      |  ::ArithmeticWholeSlideFilter
#      |
#      |  Method resolution order:
#      |      ArithmeticWholeSlideFilter
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  getExpression(...)
#      |
#      |  getProcessedLevel(...)
#      |
#      |  getProgressMonitor(...)
#      |
#      |  process(...)
#      |
#      |  setExpression(...)
#      |
#      |  setInput(...)
#      |
#      |  setOutput(...)
#      |
#      |  setProcessedLevel(...)
#      |
#      |  setProgressMonitor(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ArithmeticWholeSlideFilter.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class ConnectedComponentsWholeSlideFilter(__builtin__.SwigPyObject)
#      |  ::ConnectedComponentsWholeSlideFilter
#      |
#      |  Method resolution order:
#      |      ConnectedComponentsWholeSlideFilter
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  getProcessedLevel(...)
#      |
#      |  getProgressMonitor(...)
#      |
#      |  getThreshold(...)
#      |
#      |  process(...)
#      |
#      |  setInput(...)
#      |
#      |  setOutput(...)
#      |
#      |  setProcessedLevel(...)
#      |
#      |  setProgressMonitor(...)
#      |
#      |  setThreshold(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ConnectedComponentsWholeSlideFilter.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class DistanceTransformWholeSlideFilter(__builtin__.SwigPyObject)
#      |  ::DistanceTransformWholeSlideFilter
#      |
#      |  Method resolution order:
#      |      DistanceTransformWholeSlideFilter
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  getProcessedLevel(...)
#      |
#      |  getProgressMonitor(...)
#      |
#      |  process(...)
#      |
#      |  setInput(...)
#      |
#      |  setOutput(...)
#      |
#      |  setProcessedLevel(...)
#      |
#      |  setProgressMonitor(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      DistanceTransformWholeSlideFilter.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class LabelStatisticsWholeSlideFilter(__builtin__.SwigPyObject)
#      |  ::LabelStatisticsWholeSlideFilter
#      |
#      |  Method resolution order:
#      |      LabelStatisticsWholeSlideFilter
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  getLabelStatistics(...)
#      |
#      |  getProcessedLevel(...)
#      |
#      |  getProgressMonitor(...)
#      |
#      |  process(...)
#      |
#      |  setInput(...)
#      |
#      |  setOutput(...)
#      |
#      |  setProcessedLevel(...)
#      |
#      |  setProgressMonitor(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      LabelStatisticsWholeSlideFilter.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class NucleiDetectionWholeSlideFilter(__builtin__.SwigPyObject)
#      |  ::NucleiDetectionWholeSlideFilter
#      |
#      |  Method resolution order:
#      |      NucleiDetectionWholeSlideFilter
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  getAlpha(...)
#      |
#      |  getBeta(...)
#      |
#      |  getCenterPoints(...)
#      |
#      |  getMaximumRadius(...)
#      |
#      |  getMinimumRadius(...)
#      |
#      |  getProcessedLevel(...)
#      |
#      |  getProgressMonitor(...)
#      |
#      |  getRadiusStep(...)
#      |
#      |  getThreshold(...)
#      |
#      |  process(...)
#      |
#      |  setAlpha(...)
#      |
#      |  setBeta(...)
#      |
#      |  setInput(...)
#      |
#      |  setMaximumRadius(...)
#      |
#      |  setMinimumRadius(...)
#      |
#      |  setOutput(...)
#      |
#      |  setProcessedLevel(...)
#      |
#      |  setProgressMonitor(...)
#      |
#      |  setRadiusStep(...)
#      |
#      |  setThreshold(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      NucleiDetectionWholeSlideFilter.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class SwigPyIterator(__builtin__.SwigPyObject)
#      |  swig::SwigPyIterator
#      |
#      |  Method resolution order:
#      |      SwigPyIterator
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(...)
#      |      x.__add__(y) <==> x+y
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __iadd__(...)
#      |      x.__iadd__(y) <==> x+=y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __isub__(...)
#      |      x.__isub__(y) <==> x-=y
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __next__(...)
#      |
#      |  __radd__(...)
#      |      x.__radd__(y) <==> y+x
#      |
#      |  __rsub__(...)
#      |      x.__rsub__(y) <==> y-x
#      |
#      |  __sub__(...)
#      |      x.__sub__(y) <==> x-y
#      |
#      |  advance(...)
#      |
#      |  copy(...)
#      |
#      |  decr(...)
#      |
#      |  distance(...)
#      |
#      |  equal(...)
#      |
#      |  incr(...)
#      |
#      |  next(...)
#      |      x.next() -> the next value, or raise StopIteration
#      |
#      |  previous(...)
#      |
#      |  value(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      swig::SwigPyIterator.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class ThresholdWholeSlideFilter(__builtin__.SwigPyObject)
#      |  ::ThresholdWholeSlideFilter
#      |
#      |  Method resolution order:
#      |      ThresholdWholeSlideFilter
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  getComponent(...)
#      |
#      |  getLowerThreshold(...)
#      |
#      |  getProcessedLevel(...)
#      |
#      |  getProgressMonitor(...)
#      |
#      |  getUpperThreshold(...)
#      |
#      |  process(...)
#      |
#      |  setComponent(...)
#      |
#      |  setInput(...)
#      |
#      |  setLowerThreshold(...)
#      |
#      |  setOutput(...)
#      |
#      |  setProcessedLevel(...)
#      |
#      |  setProgressMonitor(...)
#      |
#      |  setUpperThreshold(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      ThresholdWholeSlideFilter.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  append(...)
#      |      appends another 'this' object
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_double(__builtin__.SwigPyObject)
#      |  std::vector< double >
#      |
#      |  Method resolution order:
#      |      vector_double
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(double)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_float(__builtin__.SwigPyObject)
#      |  std::vector< float >
#      |
#      |  Method resolution order:
#      |      vector_float
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(float)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_int(__builtin__.SwigPyObject)
#      |  std::vector< int >
#      |
#      |  Method resolution order:
#      |      vector_int
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(int)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_long_long(__builtin__.SwigPyObject)
#      |  std::vector< long long >
#      |
#      |  Method resolution order:
#      |      vector_long_long
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(long long)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_string(__builtin__.SwigPyObject)
#      |  std::vector< std::string >
#      |
#      |  Method resolution order:
#      |      vector_string
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(std::string)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_uint(__builtin__.SwigPyObject)
#      |  std::vector< unsigned int >
#      |
#      |  Method resolution order:
#      |      vector_uint
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(unsigned int)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_unsigned_long_long(__builtin__.SwigPyObject)
#      |  std::vector< unsigned long long >
#      |
#      |  Method resolution order:
#      |      vector_unsigned_long_long
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(unsigned long long)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
#     class vector_vector_float(__builtin__.SwigPyObject)
#      |  std::vector< std::vector< float > >
#      |
#      |  Method resolution order:
#      |      vector_vector_float
#      |      __builtin__.SwigPyObject
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __delslice__(...)
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __getslice__(...)
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __init__(...)
#      |      x.__init__(...) initializes x; see help(type(x)) for signature
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __nonzero__(...)
#      |      x.__nonzero__() <==> x != 0
#      |
#      |  __setitem__(...)
#      |      x.__setitem__(i, y) <==> x[i]=y
#      |
#      |  __setslice__(...)
#      |
#      |  append(...)
#      |
#      |  assign(...)
#      |
#      |  back(...)
#      |
#      |  begin(...)
#      |
#      |  capacity(...)
#      |
#      |  clear(...)
#      |
#      |  empty(...)
#      |
#      |  end(...)
#      |
#      |  erase(...)
#      |
#      |  front(...)
#      |
#      |  get_allocator(...)
#      |
#      |  insert(...)
#      |
#      |  iterator(...)
#      |
#      |  pop(...)
#      |
#      |  pop_back(...)
#      |
#      |  push_back(...)
#      |
#      |  rbegin(...)
#      |
#      |  rend(...)
#      |
#      |  reserve(...)
#      |
#      |  resize(...)
#      |
#      |  size(...)
#      |
#      |  swap(...)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      std::vector<(std::vector<(float)>)>.__dict__
#      |
#      |  this
#      |
#      |  thisown
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of SwigPyObjectType object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.SwigPyObject:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __hex__(...)
#      |      x.__hex__() <==> hex(x)
#      |
#      |  __int__(...)
#      |      x.__int__() <==> int(x)
#      |
#      |  __long__(...)
#      |      x.__long__() <==> long(x)
#      |
#      |  __oct__(...)
#      |      x.__oct__() <==> oct(x)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  acquire(...)
#      |      acquires ownership of the pointer
#      |
#      |  disown(...)
#      |      releases ownership of the pointer
#      |
#      |  next(...)
#      |      returns the next 'this' object
#      |
#      |  own(...)
#      |      returns/sets ownership of the pointer
#
# FUNCTIONS
#     SWIG_PyInstanceMethod_New(...)
#
# DATA
#     ASAP_VERSION_STRING = '1.7.1'
#     cvar = <Swig global variables>

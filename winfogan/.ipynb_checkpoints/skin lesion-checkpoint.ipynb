# %%
import os
from sklearn.datasets import fetch_mldata
import random
import torch
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torch.nn as nn
import torch.nn.parallel
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
from torch.autograd import Variable

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import cv2
import numpy as np

torch.cuda.set_device(4)

# %%
""" ==================== MNIST ======================== """

def get_mnist():
    mnist = fetch_mldata('MNIST original',data_home="/home/hubo/test/")
    np.random.seed(1234) # set seed for deterministic ordering
   #p = np.datacom.permutation(mnist.data.shape[0])
   #X = mnist.data[p]
    X = mnist.data.reshape((70000, 28, 28))

    X = np.asarray([cv2.resize(x, (64,64)) for x in X])

    X = X.astype(np.float32)/(255.0/2) - 1.0
    X = X.reshape((70000, 1, 64, 64)) 
    X = np.tile(X, (1, 3, 1, 1))
    X_train = X[:60000]
    X_test = X[60000:70000]
    p = np.random.permutation(60000)
    X_train = X_train[p]
    
    return X_train.reshape(60000,1,3,64,64)

# %%
""" ==================== DATASET ======================== """
def dataset_img():
    root_dir = './upload/'
    imageList = os.listdir(root_dir)
   # print (imageList)
    X_train = np.zeros((len(imageList),3,64,64),dtype=np.float32)
    m = 0

    for n in imageList:
        n = root_dir + n
        img = cv2.imread(n)
        X = cv2.resize(np.array(img, dtype=np.float32)[0:600,0:600,:], (64,64))[:,:,::-1].transpose((2,0,1))
        X = X.astype(np.float32)/(255.0/2) - 1.0
        X = X.reshape((1, 3, 64, 64))
        X_train[m,:,:,:] = X
        m = m+1
    
    np.random.seed(1234) # set seed for deterministic ordering

    return X_train.reshape(1220,1,3,64,64)

# %%
""" ==================== DATASET ======================== """

def dataset_img_resize():
    X_train = np.zeros(0)
    root_dir = '/home/hubo/notebook/data/skin lesion/'
    imageList = os.listdir(root_dir)
    m = 0
    
    for n in imageList:
        n = root_dir + n
        print (n)
        img = cv2.imread(n, 3)
        hight, width = img.shape[0], img.shape[1]
        q = 1

        resize = cv2.resize(img[hight/2-300:hight/2+300,width/2-300:width/2+300,:],(64,64))
        resize = resize[:,:,::-1].transpose((2,0,1))
        resize = resize.astype(np.float32)/(255.0/2) - 1.0
        resize = resize.reshape((1, 3, 64, 64))
        q+=1
        if X_train.shape[0] == 0:
            X_train = resize.reshape((1,1,3,64,64)).astype(np.float32)
        else:
            X_train = np.concatenate((X_train,resize.reshape((1,1,3,64,64))),axis=0)
                    #print (X_train.shape)
            
    np.random.seed(1234) # set seed for deterministic ordering
    p = np.random.permutation(X_train.shape[0])
    X_train = X_train[p]
    return X_train

X_train = dataset_img_resize()
X_train.shape
# Out:
# /home/hubo/notebook/data/skin lesion/ISIC_0011385.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009905.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000159.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000105.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009883.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009991.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010575.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000067.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000263.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000002.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009962.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000030.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000426.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000121.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010487.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010094.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000049.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000080.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011303.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010223.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000120.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000292.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010064.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011346.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000556.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000116.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010218.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000322.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010480.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011229.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000140.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011173.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000029.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000274.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010344.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000376.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009909.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010070.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000061.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010080.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000097.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000118.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010052.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011135.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000294.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000199.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000480.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009987.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010334.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000457.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010441.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000046.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000382.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000010.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000119.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000391.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000455.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009897.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000142.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000186.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000367.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011348.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000148.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000245.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000551.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010212.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000038.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010593.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009871.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000483.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000001.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010595.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000349.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010168.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010364.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000152.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010569.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009981.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010263.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011097.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011326.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010247.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011127.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000157.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011079.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009961.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000366.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000109.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000347.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010246.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010467.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011123.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011099.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000081.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010439.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011398.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010087.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011322.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000244.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000063.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000204.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011121.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000091.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009919.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000379.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001119.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000028.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000068.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011218.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000252.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000386.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010060.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011397.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010320.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000269.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010351.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000281.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010040.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010570.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011169.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010105.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010017.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010178.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000025.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010066.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000544.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011220.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010074.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010329.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011353.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000000.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000189.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011126.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011207.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010327.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000524.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010044.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010464.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000112.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009964.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000100.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000471.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010325.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009971.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011161.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000032.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011317.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010573.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011223.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000453.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000275.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011230.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010337.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000498.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010249.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010585.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009912.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011144.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010557.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000123.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010213.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010091.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010042.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009877.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011165.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010065.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010083.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000150.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010589.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000542.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010858.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009933.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001102.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010333.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009986.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000409.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000171.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000467.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000237.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010225.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010332.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000190.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001140.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009972.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000278.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000127.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000307.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000423.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000236.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009973.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000019.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000519.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011215.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009938.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000277.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009949.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010443.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010220.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009884.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011082.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000344.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000192.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009911.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000179.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010265.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010010.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011210.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011146.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000077.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011327.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000153.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000303.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000283.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011383.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010090.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010844.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000293.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000095.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000543.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010362.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009895.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000415.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000316.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000133.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011102.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000383.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000034.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000128.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000503.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001118.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000463.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000185.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011211.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000009.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011296.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000345.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010317.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011343.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000042.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010566.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000143.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010590.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010054.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010191.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011114.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000413.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000035.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000154.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010019.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011358.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010081.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000181.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010862.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000359.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011203.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000552.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000395.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000075.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000235.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010357.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000096.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009873.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010029.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011315.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000505.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011119.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000493.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010015.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000243.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000351.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000554.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010267.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010184.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011084.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000301.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000224.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000445.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011118.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000065.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011382.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000062.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011163.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010021.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009968.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009974.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000507.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000021.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010093.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000358.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000122.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000221.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010240.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009969.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000390.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000260.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000451.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000434.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010450.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000073.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011136.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009914.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010479.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010356.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010493.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010558.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010562.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009893.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000361.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010219.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011366.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010440.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000486.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000342.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009925.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010476.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000282.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000082.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011214.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000255.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010330.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011159.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000108.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011170.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000469.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009917.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000317.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000162.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000352.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000520.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011328.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010367.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000103.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011166.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000535.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011157.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000026.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000079.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009941.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010005.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000251.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000229.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000094.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000146.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010186.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009960.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000363.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000151.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010203.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000261.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010462.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010341.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000522.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000206.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011141.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009932.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010568.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010382.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011354.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000262.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000481.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000219.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010069.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000093.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009915.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000416.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000256.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010860.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000364.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010857.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000214.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009868.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000350.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000336.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010488.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000439.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010468.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009935.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011117.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000412.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010358.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010043.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000396.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000496.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000324.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011085.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000085.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000045.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009963.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000431.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011140.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010067.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000442.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000360.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000332.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000268.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011345.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000477.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000058.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000086.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010053.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000315.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000410.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011297.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010075.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010475.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011217.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010567.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000074.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010864.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011362.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000385.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000338.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000348.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000207.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000048.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011306.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010237.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000473.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000452.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000131.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011208.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000504.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010586.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010025.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001148.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000016.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000147.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000331.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000156.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000468.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010490.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010000.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000054.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000355.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000166.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000139.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010861.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009896.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000191.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001105.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000443.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000461.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000059.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011393.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010472.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000247.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011331.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000546.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000041.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000528.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000242.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011324.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000381.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010497.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011341.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000491.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000488.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010471.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000208.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000397.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000447.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000145.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000055.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000321.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010492.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010185.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000211.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009976.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010571.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009942.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010465.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000205.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009966.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000220.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011357.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000521.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011115.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000155.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011226.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000500.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010251.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000039.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000285.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001126.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000541.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000485.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000370.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010438.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000209.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010102.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011131.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000216.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009929.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010380.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000089.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000436.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000276.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000047.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000353.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009899.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000203.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010554.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011145.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000326.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000369.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010318.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000474.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000264.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000458.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009936.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000215.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010078.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011124.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000288.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000313.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000130.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010852.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000184.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000044.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000545.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000372.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000516.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010051.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010256.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010244.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000403.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000182.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000374.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010342.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010853.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000514.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009888.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000427.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000384.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000225.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010104.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011088.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000223.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000465.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000011.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000297.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000444.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000548.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010352.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000110.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000008.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010014.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010176.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009870.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000511.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010339.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000460.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011339.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011387.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000031.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000018.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011304.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011095.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010006.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000387.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000050.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000314.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010442.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000087.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009939.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010447.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000137.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000517.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000290.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000167.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000555.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000300.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000217.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001152.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010046.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000530.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000532.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010036.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009910.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011352.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010851.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010371.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010473.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010461.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000454.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010205.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000134.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009875.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010174.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000346.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009951.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000124.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010022.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010233.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000240.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010350.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011212.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000104.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000531.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000330.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000492.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000017.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000329.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011199.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009937.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000024.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000295.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010266.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000341.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000078.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011164.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011158.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010262.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011137.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000475.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011332.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000259.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000365.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000538.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000529.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009921.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000419.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000495.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010466.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010365.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000536.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011380.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011330.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011225.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009940.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000265.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009950.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009979.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010372.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010194.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000051.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000250.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000232.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011130.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000506.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010003.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000280.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010455.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010458.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010032.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010236.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010024.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000193.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010182.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009947.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000421.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010594.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010435.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000135.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010581.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000478.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000513.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000218.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010226.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009967.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011402.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010481.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010035.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010577.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011400.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010227.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0011100.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009953.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000408.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000176.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000163.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000523.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0009975.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000425.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0001134.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010241.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000102.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010436.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0010602.jpg
# /home/hubo/notebook/data/skin lesion/ISIC_0000489.jpg
# (680, 1, 3, 64, 64)

# %%
np.save('/home/hubo/notebook/data/skinlesion.npy',X_train)

# %%
X_train = Variable(torch.FloatTensor(X_train))
train_loader = torch.utils.data.TensorDataset(X_train,X_train)
dataiter = iter(train_loader)

# %%
def visual(X):
    assert len(X.shape) == 4
    X = X.transpose((0, 2, 3, 1))
    X = (X+1.0)*(255.0/2.0)
    X = X.reshape(X.shape[1],X.shape[2],X.shape[3])
 #   X = X[:,:,::-1]
    return np.uint8(X) #  cv2.waitKey(1)

def fill_buf(buf, i, img, shape):
    n = buf.shape[0]/shape[1]
    m = buf.shape[1]/shape[0]

    sx = (i%m)*shape[0]
    sy = (i/m)*shape[1]
    buf[sy:sy+shape[1], sx:sx+shape[0], :] = img

# %%
img,_ = dataiter.next()
img = img.data.numpy()

X = visual(img)
plt.imshow(X)

# %%
#images, labels = dataiter.next()
#visual('qqq', images.data.numpy())

# %%
mb_size = 32
Z_dim = 16
X_dim = 64
y_dim = 64
h_dim = 128
cnt = 0
lr = 1e-3

# %%
def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / np.sqrt(in_dim / 2.)
    return Variable(torch.randn(*size) * xavier_stddev, requires_grad=True)

# %%
""" ==================== GENERATOR ======================== """
import torch.nn.parallel

class _netG(nn.Module):
    def __init__(self, ngpu, isize = 64, nz = 149, nc = 3, ngf = 64, n_extra_layers=0):
        super(_netG, self).__init__()
        self.ngpu = ngpu
        assert isize % 16 == 0, "isize has to be a multiple of 16"

        cngf, tisize = ngf//2, 4
        while tisize != isize:
            cngf = cngf * 2
            tisize = tisize * 2

        main = nn.Sequential()
        # input is Z, going into a convolution
        main.add_module('initial.{0}-{1}.convt'.format(nz, cngf),
                        nn.ConvTranspose2d(nz, cngf, 4, 1, 0, bias=False))
        main.add_module('initial.{0}.batchnorm'.format(cngf),
                        nn.BatchNorm2d(cngf))
        main.add_module('initial.{0}.relu'.format(cngf),
                        nn.ReLU(True))

        csize, cndf = 4, cngf
        while csize < isize//2:
            main.add_module('pyramid.{0}-{1}.convt'.format(cngf, cngf//2),
                            nn.ConvTranspose2d(cngf, cngf//2, 4, 2, 1, bias=False))
            main.add_module('pyramid.{0}.batchnorm'.format(cngf//2),
                            nn.BatchNorm2d(cngf//2))
            main.add_module('pyramid.{0}.relu'.format(cngf//2),
                            nn.ReLU(True))
            cngf = cngf // 2
            csize = csize * 2

        # Extra layers
        for t in range(n_extra_layers):
            main.add_module('extra-layers-{0}.{1}.conv'.format(t, cngf),
                            nn.Conv2d(cngf, cngf, 3, 1, 1, bias=False))
            main.add_module('extra-layers-{0}.{1}.batchnorm'.format(t, cngf),
                            nn.BatchNorm2d(cngf))
            main.add_module('extra-layers-{0}.{1}.relu'.format(t, cngf),
                            nn.ReLU(True))

        main.add_module('final.{0}-{1}.convt'.format(cngf, nc),
                        nn.ConvTranspose2d(cngf, nc, 4, 2, 1, bias=False))
        main.add_module('final.{0}.tanh'.format(nc),
                        nn.Tanh())
        self.main = main

    def forward(self, input):
        gpu_ids = None
        if isinstance(input.data, torch.cuda.FloatTensor) and self.ngpu > 1:
            gpu_ids = range(self.ngpu)
        return self.main(input)
    
#noise = Variable(torch.randn(1, 74))
netG = _netG(6)
print (netG)
#netG(noise)
# Out:
# _netG (
#   (main): Sequential (
#     (initial.149-512.convt): ConvTranspose2d(149, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (initial.512.batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     (initial.512.relu): ReLU (inplace)
#     (pyramid.512-256.convt): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (pyramid.256.batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (pyramid.256.relu): ReLU (inplace)
#     (pyramid.256-128.convt): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (pyramid.128.batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (pyramid.128.relu): ReLU (inplace)
#     (pyramid.128-64.convt): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (pyramid.64.batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (pyramid.64.relu): ReLU (inplace)
#     (final.64-3.convt): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (final.3.tanh): Tanh ()
#   )
# )

# %%
""" ==================== DISCRIMINATOR  ======================== """

class _netD(nn.Module):
    def __init__(self, isize = 64, nz = 149, nc = 3, ndf = 64, ngpu = 6, n_extra_layers=0):
        super(_netD, self).__init__()
        self.ngpu = ngpu
        assert isize % 16 == 0, "isize has to be a multiple of 16"

        main = nn.Sequential()
        # input is nc x isize x isize
        main.add_module('initial.conv.{0}-{1}'.format(nc, ndf),
                        nn.Conv2d(nc, ndf, 4, 2, 1, bias=False))
        main.add_module('initial.relu.{0}'.format(ndf),
                        nn.LeakyReLU(0.2, inplace=True))
        csize, cndf = isize / 2, ndf

        # Extra layers
        for t in range(n_extra_layers):
            main.add_module('extra-layers-{0}.{1}.conv'.format(t, cndf),
                            nn.Conv2d(cndf, cndf, 3, 1, 1, bias=False))
            main.add_module('extra-layers-{0}.{1}.batchnorm'.format(t, cndf),
                            nn.BatchNorm2d(cndf))
            main.add_module('extra-layers-{0}.{1}.relu'.format(t, cndf),
                            nn.LeakyReLU(0.2, inplace=True))

        while csize > 4:
            in_feat = cndf
            out_feat = cndf * 2
            main.add_module('pyramid.{0}-{1}.conv'.format(in_feat, out_feat),
                            nn.Conv2d(in_feat, out_feat, 4, 2, 1, bias=False))
            main.add_module('pyramid.{0}.batchnorm'.format(out_feat),
                            nn.BatchNorm2d(out_feat))
            main.add_module('pyramid.{0}.relu'.format(out_feat),
                            nn.LeakyReLU(0.2, inplace=True))
            cndf = cndf * 2
            csize = csize / 2

        # state size. K x 4 x 4
       # main.add_module('final.{0}-{1}.conv'.format(cndf, 1),
       #                 nn.Conv2d(cndf, 1, 4, 1, 0, bias=False))
        self.main = main
        
    def forward(self, input):
        gpu_ids = None
        if isinstance(input.data, torch.cuda.FloatTensor) and self.ngpu > 1:
            gpu_ids = range(self.ngpu)
        return self.main(input)


netD = _netD()
#print (netD)

generate = Variable(torch.zeros(1,3,64,64))
#print netD(generate)

# %%
class _netD_D(nn.Module):
    def __init__(self):
        super(_netD_D, self).__init__()
        self.conv = nn.Conv2d(512, 1, 4, 1, 0, bias=False)
        
    def forward(self, x):
        x = self.conv(x)
        return x
    
class _netD_Q(nn.Module):
    def __init__(self):
        super(_netD_Q, self).__init__()
        # input is Z, going into a convolution
        self.conv = nn.Conv2d(512, 10, 4, 1, 0, bias=False)
        self.softmax = nn.Softmax()
        
    def forward(self, x):
        x = self.conv(x)
        x = x.view(1,-1)
        x = self.softmax(x)
     #   x = x.view(1,-1,1,1)
        return x
    
class _netD_Q_2(nn.Module):
    def __init__(self):
        super(_netD_Q_2, self).__init__()
        # input is Z, going into a convolution
        self.conv = nn.Conv2d(512, 10, 4, 1, 0, bias=False)
        self.softmax = nn.Softmax()
        
    def forward(self, x):
        x = self.conv(x)
        x = x.view(1,-1)
        x = self.softmax(x)
     #   x = x.view(1,-1,1,1)
        return x

class _netD_Q_3(nn.Module):
    def __init__(self):
        super(_netD_Q_3, self).__init__()
        # input is Z, going into a convolution
        self.conv = nn.Conv2d(512, 1, 4, 1, 0, bias=False)
        
    def forward(self, x):
        x = self.conv(x)
        x = x.view(1,-1)
        return x

    
netD_D = _netD_D()
netD_Q = _netD_Q()
netD_Q_2 = _netD_Q_2()
netD_Q_3 = _netD_Q_3()


print (netD_D)
print (netD_Q)
#output = netD(x,'D')
#output
generate = Variable(torch.zeros(1,3,64,64))
netD_Q(netD(generate)).size()
# Out:
# _netD_D (
#   (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
# _netD_Q (
#   (conv): Conv2d(512, 10, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (softmax): Softmax ()
# )
# torch.Size([1, 10])

# %%
""" ==================== DISCRIMINATOR  ======================== 
class _netD_D(nn.Module):
    def __init__(self):
        super(_netD_D, self).__init__()
        self.fc2 = nn.Linear(1024, 1)
        
    def forward(self, x):
        x = self.fc2(x)
      #  x = x.sigmoid()
        x = x.view(-1)
        return x
    
class _netD_Q(nn.Module):
    def __init__(self):
        super(_netD_Q, self).__init__()
        # input is Z, going into a convolution
        self.fc4 = nn.Linear(1024, 10)
        
    def forward(self, x):
        x = self.fc4(x)
      #  x = x.sigmoid()
        return x
    
netD_D = _netD_D()
netD_Q = _netD_Q()

print (netD_D)
print (netD_Q)
#output = netD(x,'D')
#output

"""
# Out:
# " ==================== DISCRIMINATOR  ======================== \nclass _netD_D(nn.Module):\n    def __init__(self):\n        super(_netD_D, self).__init__()\n        self.fc2 = nn.Linear(1024, 1)\n        \n    def forward(self, x):\n        x = self.fc2(x)\n      #  x = x.sigmoid()\n        x = x.view(-1)\n        return x\n    \nclass _netD_Q(nn.Module):\n    def __init__(self):\n        super(_netD_Q, self).__init__()\n        # input is Z, going into a convolution\n        self.fc4 = nn.Linear(1024, 10)\n        \n    def forward(self, x):\n        x = self.fc4(x)\n      #  x = x.sigmoid()\n        return x\n    \nnetD_D = _netD_D()\nnetD_Q = _netD_Q()\n\nprint (netD_D)\nprint (netD_Q)\n#output = netD(x,'D')\n#output\n\n"

# %%
def weights_init(m):
    classname = m.__class__.__name__
   # print (classname)
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
        print (classname)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)
        print (classname)

netG.apply(weights_init)
netD.apply(weights_init)
netD_Q.apply(weights_init)
netD_Q_2.apply(weights_init)
netD_Q_3.apply(weights_init)
netD_D.apply(weights_init)
# Out:
# ConvTranspose2d
# BatchNorm2d
# ConvTranspose2d
# BatchNorm2d
# ConvTranspose2d
# BatchNorm2d
# ConvTranspose2d
# BatchNorm2d
# ConvTranspose2d
# Conv2d
# Conv2d
# BatchNorm2d
# Conv2d
# BatchNorm2d
# Conv2d
# BatchNorm2d
# Conv2d
# Conv2d
# Conv2d
# Conv2d
# _netD_D (
#   (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %%
""" ====================== OPTIMISER ========================== """

optimizerD = optim.RMSprop([
                {'params': netD.parameters()},
                {'params': netD_D.parameters()}
            ], 0.00005)

optimizerG = optim.RMSprop(netG.parameters(), lr = 0.00005)

optimizerQ = optim.RMSprop([
                {'params': netG.parameters()},            
                {'params': netD.parameters()},
                {'params': netD_Q.parameters()},
                {'params': netD_Q_2.parameters()},
                {'params': netD_Q_3.parameters()}
            ], 0.00005)

# %%
input = torch.FloatTensor(1, 3, 64, 64)
noise = torch.FloatTensor(1, 149,1 ,1 )

fixed_noise = torch.FloatTensor(np.random.multinomial(1, 10*[0.1], size=1))
c = torch.FloatTensor(np.random.multinomial(1, 10*[0.1], size=1))
c2 = torch.FloatTensor(np.random.multinomial(1, 10*[0.1], size=1))
c3 = torch.FloatTensor(np.random.uniform(-1,1,(1,1)))
z = torch.randn(1, 128,1,1)

label = torch.FloatTensor(1)

real_label = 1
fake_label = 0

# %%
c3.uniform_(-1,1)
# Out:
# -0.3498
# [torch.FloatTensor of size 1x1]

# %%
criterion = nn.BCELoss()
criterion_logli = nn.NLLLoss()
criterion_mse = nn.MSELoss()

# %%
netD = netD.cuda()
netG = netG.cuda()
netD_D = netD_D.cuda()
netD_Q = netD_Q.cuda()
netD_Q_2 = netD_Q_2.cuda()
netD_Q_3 = netD_Q_3.cuda()
criterion, criterion_logli, criterion_mse = criterion.cuda(), criterion_logli.cuda(), criterion_mse.cuda()
input, label = input.cuda(), label.cuda()
noise, fixed_noise = noise.cuda(), fixed_noise.cuda()
z, c, c2, c3 = z.cuda(), c.cuda(), c2.cuda(), c3.cuda()

# %%
input = Variable(input)
label = Variable(label)
noise = Variable(noise)
fixed_noise = Variable(fixed_noise)
c = Variable(c)
c2 = Variable(c2)
c3 = Variable(c3)
z = Variable(z)

# %%
""" ======================TRAIN========================== """

def sample_c():
    rand_c = np.random.multinomial(1, 10*[0.1], size=1)
    rand_c = torch.from_numpy(rand_c.astype('float32'))
    return rand_c

def zero_grad():
    netD.zero_grad()
    netD_Q.zero_grad()
    netD_Q_2.zero_grad()
    netD_Q_3.zero_grad()
    netD_D.zero_grad()
    netG.zero_grad()

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display

one = torch.FloatTensor([1]).cuda()
mone = one * -1
mone = mone.cuda()
gen_iterations = 0

for epoch in range(100000):
    
    dataiter = iter(train_loader)
    i = 0
    
    while i < len(train_loader):
        for p in netD.parameters():
            p.data.clamp_(-0.01, 0.01)
        for p in netD_D.parameters():
            p.data.clamp_(-0.01, 0.01)

        if gen_iterations < 25 or gen_iterations % 500 == 0:
            Diters = 20
        else:
            Diters = 5
        
        j = 0
        while j < Diters and i < len(train_loader):
            j += 1
            image_, _ = dataiter.next()
            i +=1
            for p in netD.parameters():
                p.data.clamp_(-0.01, 0.01)
            for p in netD_D.parameters():
                p.data.clamp_(-0.01, 0.01)
    #train on D
    #sending real data 
            zero_grad()
            input.data.copy_(image_.data)
            label.data.resize_(1).fill_(real_label)
            D_real =netD_D(netD(input))
            #D_loss_real = criterion(D_real, label)
            D_real.backward(one)

    #sending noise
            z.data.normal_(0, 1)
            c.data.copy_(sample_c())
            c2.data.copy_(sample_c())
            c3.data.uniform_(-1,1)
            noise = torch.cat([c,c2,c3,z],1)
        
            G_sample = netG(noise)
            D_fake = netD_D(netD(G_sample))
            label.data.resize_(1).fill_(fake_label)
           # D_loss_fake = criterion(D_fake, label)
            D_fake.backward(mone)
        
    # update D
            optimizerD.step()
    

    # update G  
        zero_grad()
        G_sample = netG(noise)
        D_fake = netD_D(netD(G_sample))
        label.data.resize_(1).fill_(real_label)
       # G_loss = criterion(D_fake, label)
        D_fake.backward(one)
        optimizerG.step()
        
        gen_iterations += 1
        
    # update Q
        zero_grad()
        G_sample = netG(noise)
        Q_c_given_x = netD_Q(netD(G_sample))
        Q_c_given_x_2 = netD_Q_2(netD(G_sample))
        Q_c_given_x_3 = netD_Q_3(netD(G_sample))
        
        crossent_loss = torch.mean(-torch.sum(c * torch.log(Q_c_given_x + 1e-8), dim=1))
       # print (Q_c_given_x)
        crossent_loss_2 = torch.mean(-torch.sum(c2 * torch.log(Q_c_given_x_2 + 1e-8), dim=1))
        crossent_loss_3 = criterion_mse(Q_c_given_x_3, c3) 

        # ent_loss = torch.mean(-torch.sum(c * torch.log(c + 1e-8), dim=1))
       # ent_loss_2 = torch.mean(-torch.sum(c2 * torch.log(c2 + 1e-8), dim=1))
       # ent_loss_3 = torch.mean(-torch.sum(c3 * torch.log(c3 + 1e-8), dim=1))

        mi_loss = crossent_loss + crossent_loss_2 + 0.1*crossent_loss_3

        mi_loss.backward()
        optimizerQ.step()
        
        if gen_iterations % 20 == 0 :
            input.data.copy_(image_.data)
            label.data.resize_(1).fill_(real_label)
            D_real =netD_D(netD(input))
            D_error = D_real - D_fake
            print (epoch, gen_iterations , -D_error.data[0],mi_loss.data[0])
            
           # image_output = visual(G_sample.data.cpu().numpy() )
          #  plt.figure(1)
          #  plt.imshow(visual(image_.data.numpy()))
          #  plt.figure(2)
         #   plt.imshow(image_output)
         #   plt.show()
            
            display.clear_output(wait=True)


    if epoch % 20 == 0:
        torch.save(netG.state_dict(), './20170302/info_skin_lesion_netG_epoch_%d.pth' % (epoch))
        print ("saved")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-5c71e14aa6f5> in <module>()
#      39             input.data.copy_(image_.data)
#      40             label.data.resize_(1).fill_(real_label)
# ---> 41             D_real =netD_D(netD(input))
#      42             #D_loss_real = criterion(D_real, label)
#      43             D_real.backward(one)
#
# /home/hubo/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     208
#     209     def __call__(self, *input, **kwargs):
# --> 210         result = self.forward(*input, **kwargs)
#     211         for hook in self._forward_hooks.values():
#     212             hook_result = hook(self, input, result)
#
# <ipython-input-13-eb867d93c003> in forward(self, input)
#      45         if isinstance(input.data, torch.cuda.FloatTensor) and self.ngpu > 1:
#      46             gpu_ids = range(self.ngpu)
# ---> 47         return self.main(input)
#      48
#      49
#
# /home/hubo/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     208
#     209     def __call__(self, *input, **kwargs):
# --> 210         result = self.forward(*input, **kwargs)
#     211         for hook in self._forward_hooks.values():
#     212             hook_result = hook(self, input, result)
#
# /home/hubo/.local/lib/python2.7/site-packages/torch/nn/modules/container.pyc in forward(self, input)
#      62     def forward(self, input):
#      63         for module in self._modules.values():
# ---> 64             input = module(input)
#      65         return input
#      66
#
# /home/hubo/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     208
#     209     def __call__(self, *input, **kwargs):
# --> 210         result = self.forward(*input, **kwargs)
#     211         for hook in self._forward_hooks.values():
#     212             hook_result = hook(self, input, result)
#
# /home/hubo/.local/lib/python2.7/site-packages/torch/nn/modules/conv.pyc in forward(self, input)
#     235     def forward(self, input):
#     236         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 237                         self.padding, self.dilation, self.groups)
#     238
#     239
#
# /home/hubo/.local/lib/python2.7/site-packages/torch/nn/functional.pyc in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      35     f = ConvNd(_pair(stride), _pair(padding), _pair(dilation), False,
#      36                _pair(0), groups)
# ---> 37     return f(input, weight, bias) if bias is not None else f(input, weight)
#      38
#      39
#
# KeyboardInterrupt:

# %%
torch.save(netG.state_dict(), './20170302/info_skin_lesion_netG_epoch_%d.pth' % (epoch))

# %%
crossent_loss_3 = criterion_mse(Q_c_given_x_3, c3)

# %%
netD_Q_2(netD(G_sample))

# %%
netD_D(netD(input))

# %%
import math
import torch.nn.functional as F

class BasicBlock(nn.Module):
    def __init__(self, in_planes, out_planes, dropRate=0.0):
        super(BasicBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.droprate = dropRate
    def forward(self, x):
        out = self.conv1(self.relu(self.bn1(x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, training=self.training)
        return torch.cat([x, out], 1)

class BottleneckBlock(nn.Module):
    def __init__(self, in_planes, out_planes, dropRate=0.0):
        super(BottleneckBlock, self).__init__()
        inter_planes = out_planes * 4
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, inter_planes, kernel_size=1, stride=1,
                               padding=0, bias=False)
        self.bn2 = nn.BatchNorm2d(inter_planes)
        self.conv2 = nn.Conv2d(inter_planes, out_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.droprate = dropRate
    def forward(self, x):
        out = self.conv1(self.relu(self.bn1(x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, inplace=False, training=self.training)
        out = self.conv2(self.relu(self.bn2(out)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, inplace=False, training=self.training)
        return torch.cat([x, out], 1)

class TransitionBlock(nn.Module):
    def __init__(self, in_planes, out_planes, dropRate=0.0):
        super(TransitionBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=1,
                               padding=0, bias=False)
        self.droprate = dropRate
    def forward(self, x):
        out = self.conv1(self.relu(self.bn1(x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, inplace=False, training=self.training)
        return F.avg_pool2d(out, 2)

class DenseBlock(nn.Module):
    def __init__(self, nb_layers, in_planes, growth_rate, block, dropRate=0.0):
        super(DenseBlock, self).__init__()
        self.layer = self._make_layer(block, in_planes, growth_rate, nb_layers, dropRate)
    def _make_layer(self, block, in_planes, growth_rate, nb_layers, dropRate):
        layers = []
        for i in range(nb_layers):
            layers.append(block(in_planes+i*growth_rate, growth_rate, dropRate))
        return nn.Sequential(*layers)
    def forward(self, x):
        return self.layer(x)

class DenseNet3(nn.Module):
    def __init__(self, depth, num_classes, growth_rate=12,
                 reduction=0.5, bottleneck=True, dropRate=0.0):
        super(DenseNet3, self).__init__()
        in_planes = 2 * growth_rate
        n = (depth - 4) / 3
        if bottleneck == True:
            n = n/2
            block = BottleneckBlock
        else:
            block = BasicBlock
        # 1st conv before any dense block
        self.conv1 = nn.Conv2d(3, in_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        # 1st block
        self.block1 = DenseBlock(n, in_planes, growth_rate, block, dropRate)
        in_planes = int(in_planes+n*growth_rate)
        self.trans1 = TransitionBlock(in_planes, int(math.floor(in_planes*reduction)), dropRate=dropRate)
        in_planes = int(math.floor(in_planes*reduction))
        # 2nd block
        self.block2 = DenseBlock(n, in_planes, growth_rate, block, dropRate)
        in_planes = int(in_planes+n*growth_rate)
        self.trans2 = TransitionBlock(in_planes, int(math.floor(in_planes*reduction)), dropRate=dropRate)
        in_planes = int(math.floor(in_planes*reduction))
        # 3rd block
        self.block3 = DenseBlock(n, in_planes, growth_rate, block, dropRate)
        in_planes = int(in_planes+n*growth_rate)
        # global average pooling and classifier
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Linear(in_planes, num_classes)
        self.in_planes = in_planes

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()
    def forward(self, x):
        out = self.conv1(x)
        out = self.trans1(self.block1(out))
        out = self.trans2(self.block2(out))
        out = self.block3(out)
        out = self.relu(self.bn1(out))
        out = F.avg_pool2d(out, 16)
        out = out.view(-1, self.in_planes)
        return self.fc(out)

model = DenseNet3(100, 2, 12, reduction=0.5,
                         bottleneck=True, dropRate=0)
model.cuda()
# Out:
# DenseNet3 (
#   (conv1): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (block1): DenseBlock (
#     (layer): Sequential (
#       (0): BottleneckBlock (
#         (bn1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (1): BottleneckBlock (
#         (bn1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): BottleneckBlock (
#         (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): BottleneckBlock (
#         (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(60, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (4): BottleneckBlock (
#         (bn1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(72, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): BottleneckBlock (
#         (bn1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(84, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (6): BottleneckBlock (
#         (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): BottleneckBlock (
#         (bn1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (8): BottleneckBlock (
#         (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (9): BottleneckBlock (
#         (bn1): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(132, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (10): BottleneckBlock (
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (11): BottleneckBlock (
#         (bn1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(156, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (12): BottleneckBlock (
#         (bn1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(168, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (13): BottleneckBlock (
#         (bn1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(180, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (14): BottleneckBlock (
#         (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (15): BottleneckBlock (
#         (bn1): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(204, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (trans1): TransitionBlock (
#     (bn1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU (inplace)
#     (conv1): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (block2): DenseBlock (
#     (layer): Sequential (
#       (0): BottleneckBlock (
#         (bn1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (1): BottleneckBlock (
#         (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): BottleneckBlock (
#         (bn1): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(132, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): BottleneckBlock (
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (4): BottleneckBlock (
#         (bn1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(156, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): BottleneckBlock (
#         (bn1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(168, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (6): BottleneckBlock (
#         (bn1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(180, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): BottleneckBlock (
#         (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (8): BottleneckBlock (
#         (bn1): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(204, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (9): BottleneckBlock (
#         (bn1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(216, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (10): BottleneckBlock (
#         (bn1): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(228, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (11): BottleneckBlock (
#         (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(240, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (12): BottleneckBlock (
#         (bn1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(252, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (13): BottleneckBlock (
#         (bn1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(264, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (14): BottleneckBlock (
#         (bn1): BatchNorm2d(276, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(276, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (15): BottleneckBlock (
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (trans2): TransitionBlock (
#     (bn1): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU (inplace)
#     (conv1): Conv2d(300, 150, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (block3): DenseBlock (
#     (layer): Sequential (
#       (0): BottleneckBlock (
#         (bn1): BatchNorm2d(150, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(150, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (1): BottleneckBlock (
#         (bn1): BatchNorm2d(162, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(162, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): BottleneckBlock (
#         (bn1): BatchNorm2d(174, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(174, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): BottleneckBlock (
#         (bn1): BatchNorm2d(186, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(186, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (4): BottleneckBlock (
#         (bn1): BatchNorm2d(198, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(198, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): BottleneckBlock (
#         (bn1): BatchNorm2d(210, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(210, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (6): BottleneckBlock (
#         (bn1): BatchNorm2d(222, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(222, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): BottleneckBlock (
#         (bn1): BatchNorm2d(234, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(234, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (8): BottleneckBlock (
#         (bn1): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(246, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (9): BottleneckBlock (
#         (bn1): BatchNorm2d(258, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(258, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (10): BottleneckBlock (
#         (bn1): BatchNorm2d(270, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(270, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (11): BottleneckBlock (
#         (bn1): BatchNorm2d(282, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(282, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (12): BottleneckBlock (
#         (bn1): BatchNorm2d(294, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(294, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (13): BottleneckBlock (
#         (bn1): BatchNorm2d(306, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(306, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (14): BottleneckBlock (
#         (bn1): BatchNorm2d(318, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(318, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (15): BottleneckBlock (
#         (bn1): BatchNorm2d(330, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU (inplace)
#         (conv1): Conv2d(330, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (bn1): BatchNorm2d(342, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU (inplace)
#   (fc): Linear (342 -> 2)
# )

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display

netG.cuda()
netG.load_state_dict(torch.load('./20170302/info_skin_lesion_netG_epoch_394.pth'))
model.load_state_dict(torch.load('./20170302/densenet_235.pth'))
plt.figure(num='output',figsize=(16,16))
z = Variable(torch.randn(1,128,1,1).cuda())
p1 = -1
p2 = -1
for k in range(0,10):
    p1+=1
    c1 = np.zeros((1,10),dtype = np.float32)
    c1[0,k] = 1
    c1 = Variable(torch.Tensor(c1).cuda())
    for q in range(0,10):
        p2+=1
        c2 = np.zeros((1,10),dtype = np.float32)
        c2[0,q] = 1
        c2 = Variable(torch.Tensor(c2).cuda())
        c3 = Variable(torch.Tensor(np.asarray([0],dtype=np.float32).reshape(1,1)).cuda())
        noise = torch.cat([c1,c2,c3,z],1)
        G_sample = netG(noise)
        image_output = visual(G_sample.data.cpu().numpy() )
        output = model(Variable(torch.Tensor(G_sample.data.cpu().numpy().astype(np.float32).reshape((1,3,64,64))).cuda()))
        plt.subplot(10,10,p1*10+p2+1) 
        plt.imshow(image_output)
        #plt.title(np.array2string(output.data.cpu().numpy().reshape((2)),precision=1),color='white')
        plt.axis('off') 
    p2=-1

plt.show()

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display

netG.cuda()
netG.load_state_dict(torch.load('./20170302/info_skin_lesion_netG_epoch_394.pth'))
plt.figure(num='output',figsize=(16,16))
z = Variable(torch.randn(1,128,1,1).cuda())
height = -1
for k in range(7,10):
    height +=1
    c1 = np.zeros((1,10),dtype = np.float32)
    c1[0,0] = 1
    c1 = Variable(torch.Tensor(c1).cuda())
    width = -1
    for q in range(7,10):
        width +=1
        c2 = np.zeros((1,10),dtype = np.float32)
        c2[0,q] = 1
        c2 = Variable(torch.Tensor(c2).cuda())
        for p in range(0,10):
            changing = (float(p)-5)
            #print (changing)
            c3 = Variable(torch.Tensor(np.asarray(changing,dtype=np.float32).reshape(1,1)).cuda())
            noise = torch.cat([c1,c2,c3,z],1)
            G_sample = netG(noise)
            image_output = visual(G_sample.data.cpu().numpy() )
            plt.subplot(9,10,height*10*3+width*10+p+1) 
            plt.imshow(image_output)     
            plt.axis('off') 

plt.show()

# %%
noise

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display

netG.load_state_dict(torch.load('./20170227/info_s_cell_netG_epoch_210.pth'))

z = Variable(torch.randn(1,138,1,1).cuda())

for k in range(0,100):
        zero_grad()
        z.data.normal_(0, 1)
             #   c = sample_c()
        noise = z
        G_sample = netG(noise)
        image_output = visual(G_sample.data.cpu().numpy() )
        pl.figure(k+1)
        pl.imshow(image_output)
        pl.show()

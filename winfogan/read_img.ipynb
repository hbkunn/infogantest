# %%
import numpy as np
cell = np.load("/home/msragpu/cellwork/data/data.npy")

# %%
def bonemarrow_cell():
    X = np.load("/home/msragpu/cellwork/data/data.npy")
    X = np.asarray([cv2.resize(x, (64,64)) for x in X])
    X = X.astype(np.float32)/(255.0/2) - 1.0
    X = X[:,:,:,::-1].transpose((0, 3,1,2))
    return X

X = bonemarrow_cell()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-d349fb7acbeb> in <module>()
#       6     return X
#       7
# ----> 8 X = bonemarrow_cell()
#
# <ipython-input-2-d349fb7acbeb> in bonemarrow_cell()
#       1 def bonemarrow_cell():
#       2     X = np.load("/home/msragpu/cellwork/data/data.npy")
# ----> 3     X = np.asarray([cv2.resize(x, (64,64)) for x in X])
#       4     X = X.astype(np.float32)/(255.0/2) - 1.0
#       5     X = X[:,:,:,::-1].transpose((0, 3,1,2))
#
# NameError: global name 'cv2' is not defined

# %%
X.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-270dd209b8a9> in <module>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
cell[0].shape
# Out:
# (32, 32, 3)

# %%
import matplotlib.pyplot as plt
import cv2
from PIL import Image

for n in range(1,9):
    cell_resize = cv2.imwrite(('./out.jpg'), cell[n])
    plt.imshow(Image.open('./out.jpg'))
    plt.show()

# %%
#cell_resize = np.int8(cell[0]).resize(32,32,3)

# %%
import matplotlib.pyplot as plt
import cv2


import matplotlib.pyplot as plt
from PIL import Image

# %%
with open("output.txt","w") as f:
        f.write(str(111,222,333)+'\n')
        f.write(str(222))
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-7-bba17bd441e5> in <module>()
#       1 with open("output.txt","w") as f:
# ----> 2         f.write(str(111,222,333)+'\n')
#       3         f.write(str(222))
#
# TypeError: str() takes at most 1 argument (3 given)

# %%
print ('{0} {1} {2} {3}'.format(1, 2 , 3 , 4))
# Out:
# 1 2 3 4

# %%
import torch

# %%
import numpy as np

clusters = np.array([
[2, 1, 2, 123, 4],
[13, 120, 3, 6, 4],
[132, 14, 5, 2, 2],
[19, 7, 73, 11, 8],
])
# Out:
# array([[  2,  13, 132,  19],
#        [  1, 120,  14,   7],
#        [  2,   3,   5,  73],
#        [123,   6,   2,  11],
#        [  4,   4,   2,   8]])

# %%
from math import *

np.transpose(clusters)
entropy, purity = [], []

for cluster in clusters:
    cluster = np.array(cluster)
    cluster = cluster / float(cluster.sum())

    e = (cluster * [log(x, 2) for x in cluster]).sum()
    p = cluster.max()
    entropy += [e]
    purity	+= [p]

counts = np.array([c.sum() for c in clusters])
coeffs = counts / float(counts.sum())
print 'entropy: ', -(coeffs * entropy).sum()
print 'purity: ', (coeffs * purity).sum()
# Out:
# entropy:  0.971603187968
# purity:  0.813067150635

# %%
np.log(x, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6cf347016bcf> in <module>()
# ----> 1 np.log(x, 2)
#
# TypeError: return arrays must be of ArrayType
